# %%
import pandas as pd

# %%
df = pd.read_excel("Dados.xlsx")

# %%
df.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion
# 0     Sánchez    NaN               0
# 1       Duffy    NaN               1
# 2  Tamburello    NaN               0
# 3     Walters    NaN               0
# 4    Erickson    NaN               0

# %%
df.loc[25:30, ["FirstName","LastName"]]
# Out:
#    FirstName  LastName
# 25     Peter     Krebs
# 26        Jo     Brown
# 27       Guy   Gilbert
# 28      Mark  McArthur
# 29    Britta     Simon
# 30    Margie     Shoop

# %%
df.loc[[1,3,4], "FirstName":"LastName"]
# Out:
#   FirstName MiddleName  LastName
# 1     Terri        Lee     Duffy
# 3       Rob        NaN   Walters
# 4      Gail          A  Erickson

# %%
df.iloc[2:6, 3:5]
# Out:
#   Title FirstName
# 2   NaN   Roberto
# 3   NaN       Rob
# 4   Ms.      Gail
# 5   Mr.    Jossef

# %%
df.iloc[[2,6], 3:8]
# Out:
#   Title FirstName MiddleName    LastName Suffix
# 2   NaN   Roberto        NaN  Tamburello    NaN
# 6   NaN     Dylan          A      Miller    NaN

# %%
df.iloc[[2,6], [True, False, True, True, True, True, True, True, True]]
# Out:
#    BusinessEntityID  NameStyle Title FirstName MiddleName    LastName Suffix  \
# 2                 3          0   NaN   Roberto        NaN  Tamburello    NaN
# 6                 7          0   NaN     Dylan          A      Miller    NaN
#
#    EmailPromotion
# 2               0
# 6               2
