# %%
import pandas as pd
df = pd.read_csv("bank.csv", encoding = "UTF-8", sep = ";")

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df[((df.balance >= 0) & (df.balance <= 1000)) & (df.housing == "yes")].loc[:,["balance","housing"]]
# Out:
#       balance housing
# 4           0     yes
# 6         307     yes
# 7         147     yes
# 8         221     yes
# 11        264     yes
# ...       ...     ...
# 4507      288     yes
# 4508      642     yes
# 4510      566     yes
# 4511      668     yes
# 4515      473     yes
#
# [1480 rows x 2 columns]

# %%
df[(df.marital == "married") & (df.education.isin(["primery","secondary"]))].shape
# Out:
# (1427, 17)

# %%
filtro = df.isin({"marital" : ["married"], "education": ["primery","secondary"]})
df[(filtro.marital) & (filtro.education)]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4513   49  blue-collar  married  secondary      no      322      no   no
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
filtro = df.isin({"marital" : ["married"], "education": ["primery","secondary"]})
df[(filtro.marital) & (filtro.education)].loc[:,["marital", "education"]]
# Out:
#       marital  education
# 1     married  secondary
# 4     married  secondary
# 7     married  secondary
# 10    married  secondary
# 11    married  secondary
# ...       ...        ...
# 4513  married  secondary
# 4514  married  secondary
# 4516  married  secondary
# 4518  married  secondary
# 4519  married  secondary
#
# [1427 rows x 2 columns]

# %%
filtro = df.isin({"marital" : ["married"], "education": ["primery","secondary"]})
df[(filtro.marital) & (filtro.education)].loc[:,"job": "education"]
# Out:
#               job  marital  education
# 1        services  married  secondary
# 4     blue-collar  married  secondary
# 7      technician  married  secondary
# 10       services  married  secondary
# 11         admin.  married  secondary
# ...           ...      ...        ...
# 4513  blue-collar  married  secondary
# 4514  blue-collar  married  secondary
# 4516     services  married  secondary
# 4518   technician  married  secondary
# 4519  blue-collar  married  secondary
#
# [1427 rows x 3 columns]
