# %%
import pandas as pd

# %%
df = pd.read_excel("Dados.xlsx",index_col=False)

# %%
df.head(15)
# Out:
#     BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                  1         EM          0   NaN       Ken          J
# 1                  2         EM          0   NaN     Terri        Lee
# 2                  3         EM          0   NaN   Roberto        NaN
# 3                  4         EM          0   NaN       Rob        NaN
# 4                  5         EM          0   Ms.      Gail          A
# 5                  6         EM          0   Mr.    Jossef          H
# 6                  7         EM          0   NaN     Dylan          A
# 7                  8         EM          0   NaN     Diane          L
# 8                  9         EM          0   NaN      Gigi          N
# 9                 10         EM          0   NaN   Michael        NaN
# 10                11         EM          0   NaN    Ovidiu          V
# 11                12         EM          0   NaN   Thierry          B
# ...

# %%
df["FirstName"].head()
# Out:
# 0        Ken
# 1      Terri
# 2    Roberto
# 3        Rob
# 4       Gail
# Name: FirstName, dtype: object

# %%
df[["FirstName", "MiddleName"]].head()
# Out:
#   FirstName MiddleName
# 0       Ken          J
# 1     Terri        Lee
# 2   Roberto        NaN
# 3       Rob        NaN
# 4      Gail          A

# %%
df.FirstName.head()
# Out:
# 0        Ken
# 1      Terri
# 2    Roberto
# 3        Rob
# 4       Gail
# Name: FirstName, dtype: object

# %%
df["nome_completo"] = df["FirstName"]+" "+df["LastName"]

# %%
df.head()
# Out:
#    BusinessEntityID PersonType  NameStyle Title FirstName MiddleName  \
# 0                 1         EM          0   NaN       Ken          J
# 1                 2         EM          0   NaN     Terri        Lee
# 2                 3         EM          0   NaN   Roberto        NaN
# 3                 4         EM          0   NaN       Rob        NaN
# 4                 5         EM          0   Ms.      Gail          A
#
#      LastName Suffix  EmailPromotion       nome_completo
# 0     Sánchez    NaN               0         Ken Sánchez
# 1       Duffy    NaN               1         Terri Duffy
# 2  Tamburello    NaN               0  Roberto Tamburello
# 3     Walters    NaN               0         Rob Walters
# 4    Erickson    NaN               0       Gail Erickson
